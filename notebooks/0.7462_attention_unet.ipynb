# %%
import os
import random

import albumentations
import cv2
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma
import pandas as pd
import rasterio
import tensorflow as tf

from IPython.display import HTML, display
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.initializers import glorot_normal, random_normal, random_uniform
from keras.layers import (
    Add, add, average, AveragePooling2D,
    Input, BatchNormalization, Activation, Dropout,
    LeakyReLU, UpSampling2D, Lambda, multiply, 
    Concatenate, concatenate, multiply, MaxPooling2D)
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.models import Model, load_model
from keras.optimizers import Adam, SGD
from pandas_path import path
from pathlib import Path
from skimage.morphology import label

plt.style.use("ggplot")
K.set_image_data_format('channels_last')  # TF dimension ordering
kinit = 'glorot_normal'
# %matplotlib inline

# %%
img_size = 512
smooth = 1

# %%
# This is where our downloaded images and metadata live locally
DATA_PATH = Path.cwd() / "training_data"
train_metadata = pd.read_csv(
    DATA_PATH / "flood-training-metadata.csv", parse_dates=["scene_start"]
)

# %%
#adding the path to the images and labels in the dataframe
train_metadata["feature_path"] = (str(DATA_PATH / "train_features")
    / train_metadata.image_id.path.with_suffix(".tif").path)

sources = ['change', 'extent', 'occurrence', 'recurrence', 'seasonality', 'transitions', 'nasadem']

for i in os.listdir('training_data/train_features'):
    for source in sources:
        if source in i:
            train_metadata[source] = DATA_PATH /'train_features' / i

train_metadata["label_path"] = (str(DATA_PATH / "train_labels")
    / train_metadata.chip_id.path.with_suffix(".tif").path)

# %%
train_metadata
# Out:
#       image_id chip_id flood_id polarization location scene_start  \
# 0     awc00_vh   awc00      awc           vh  Bolivia  2018-02-15
# 1     awc00_vv   awc00      awc           vv  Bolivia  2018-02-15
# 2     awc01_vh   awc01      awc           vh  Bolivia  2018-02-15
# 3     awc01_vv   awc01      awc           vv  Bolivia  2018-02-15
# 4     awc02_vh   awc02      awc           vh  Bolivia  2018-02-15
# ...        ...     ...      ...          ...      ...         ...
# 1079  wvy29_vv   wvy29      wvy           vv       UK  2019-02-15
# 1080  wvy30_vh   wvy30      wvy           vh       UK  2019-02-15
# 1081  wvy30_vv   wvy30      wvy           vv       UK  2019-02-15
# 1082  wvy31_vh   wvy31      wvy           vh       UK  2019-02-15
# 1083  wvy31_vv   wvy31      wvy           vv       UK  2019-02-15
#
#                                            feature_path  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                                  change  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                             transitions  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                              recurrence  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                                  extent  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                             seasonality  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                                 nasadem  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                              occurrence  \
# 0     /home/jovyan/thesis/training_data/train_featur...
# 1     /home/jovyan/thesis/training_data/train_featur...
# 2     /home/jovyan/thesis/training_data/train_featur...
# 3     /home/jovyan/thesis/training_data/train_featur...
# 4     /home/jovyan/thesis/training_data/train_featur...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_featur...
# 1080  /home/jovyan/thesis/training_data/train_featur...
# 1081  /home/jovyan/thesis/training_data/train_featur...
# 1082  /home/jovyan/thesis/training_data/train_featur...
# 1083  /home/jovyan/thesis/training_data/train_featur...
#
#                                              label_path
# 0     /home/jovyan/thesis/training_data/train_labels...
# 1     /home/jovyan/thesis/training_data/train_labels...
# 2     /home/jovyan/thesis/training_data/train_labels...
# 3     /home/jovyan/thesis/training_data/train_labels...
# 4     /home/jovyan/thesis/training_data/train_labels...
# ...                                                 ...
# 1079  /home/jovyan/thesis/training_data/train_labels...
# 1080  /home/jovyan/thesis/training_data/train_labels...
# 1081  /home/jovyan/thesis/training_data/train_labels...
# 1082  /home/jovyan/thesis/training_data/train_labels...
# 1083  /home/jovyan/thesis/training_data/train_labels...
#
# [1084 rows x 15 columns]

# %% [markdown]
# # Train Test Split

# %%
random.seed(12) 

# Sample 3 random floods for validation set
difficult_ids = ['hxu','jja','pxs']
flood_ids = list(set(train_metadata.flood_id.unique().tolist())-set(difficult_ids))
val_flood_ids = random.sample(flood_ids, 3)
val_flood_ids
# Out:
# ['awc', 'qus', 'qxb']

# %%
test = train_metadata[train_metadata.flood_id.isin(val_flood_ids)]
train = train_metadata[~train_metadata.flood_id.isin(val_flood_ids)]

# %%
def get_paths_by_chip(image_level_df):
    """
    Function that takes as input the meta_dataframe
    and return a dataframe with the chip id and both path for vv and vh.
    """
    
    paths = []
    for chip, group in image_level_df.groupby("chip_id"):
        vv_path = group[group.polarization == "vv"]["feature_path"].values[0]
        vh_path = group[group.polarization == "vh"]["feature_path"].values[0]
        nasadem_path = group["nasadem"].values[0]
        change_path = group["change"].values[0]
        extent_path = group["extent"].values[0]
        occurrence_path = group["occurrence"].values[0]
        recurrence_path = group["recurrence"].values[0]
        seasonality_path = group["seasonality"].values[0]
        transitions_path = group["transitions"].values[0]
        paths.append([chip, vv_path, vh_path, nasadem_path, change_path, extent_path, occurrence_path, recurrence_path,
                      seasonality_path, transitions_path])
    return pd.DataFrame(paths, columns=["chip_id", "vv_path", "vh_path", "nasadem", "change", "extent", "occurrence",
                                        "recurrence", "seasonality", "transitions"])

# %%
# Separate features from labels
test_meta_x = get_paths_by_chip(test)
test_meta_y = test[["chip_id", "label_path"]].drop_duplicates().reset_index(drop=True)

train_meta_x = get_paths_by_chip(train)
train_meta_y = train[["chip_id", "label_path"]].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# # Get images

# %%
from IPython.display import HTML, display
def progress(value, max=100):
    return HTML("""
        <progress value='{value}', max='{max}', style='width: 100%'> {value} </progress>
    """.format(value=value, max=max))

# %%
def numpy_mask(image_path):
    with rasterio.open(image_path) as img:
        return img.read(1, masked=True)

# %%
def get_images(feature_path, label_path):
    features = []
    labels = []
    masks = []

    #progress bar
    out1 = display(progress(0, 100), display_id=True)
    out2 = display(progress(0, 100), display_id=True)

    paths = label_path['label_path'].to_list()
    nb_cols = len(paths)
    #load labels
    for i in range(nb_cols):
        with rasterio.open(paths[i]) as lp:
            img = lp.read(1)

        #create a list of mask for missing pixels
        mask = np.zeros(img.shape, dtype=np.uint8)
        mask[np.where(img == 255)] = 0

        labels.append(ma.array(img.astype('float32'), mask = mask))
        masks.append(mask)

        out1.update(progress((i/nb_cols)*100, 100))

    #load features
    cols = ["vv_path", "vh_path", "nasadem", "change", "extent", "seasonality", "occurrence", "recurrence", "transitions"]
    nb_cols = len(feature_path)
    for row in range(nb_cols) :
        images = []
        for col in cols:
            with rasterio.open(feature_path.loc[row, col]) as img:
          #load the tif file
                if(col in ["vv_path", "vh_path"]):
              #apply transformation: clip values out of -30;0 range and map them to 0; 255 range then convert to uint8
                    images.append(ma.array(np.uint8(np.clip(img.read(1), -30, 0)*(-8.5)), mask = masks[row]))
                elif col == "nasadem":
              #clip values > 255 and converto to uint8
                    images.append(ma.array(np.uint8(np.clip(img.read(1), 0, 255)), mask = masks[row]))
                else:
              #no transformation, values are already between 0 and 255 and in uint8 format
                  images.append(ma.array(img.read(1), mask = masks[row]))
        features.append(np.stack(images, axis=-1))
        out2.update(progress((row/nb_cols)*100, 100))       
    #return len(features), len(labels)
    return np.array(features), np.array(labels)

# %%
train_x, train_y = get_images(train_meta_x, train_meta_y)
test_x, test_y = get_images(test_meta_x, test_meta_y)
# Out:
#         <progress value='99.78021978021978', max='100', style='width: 100%'> 99.78021978021978 </progress>
#         <progress value='99.78021978021978', max='100', style='width: 100%'> 99.78021978021978 </progress>
#         <progress value='98.85057471264368', max='100', style='width: 100%'> 98.85057471264368 </progress>
#         <progress value='98.85057471264368', max='100', style='width: 100%'> 98.85057471264368 </progress>

# %% [markdown]
# # Image augmentations

# %%
random.seed(12)

transform = albumentations.Compose(
    [
        albumentations.RandomRotate90(),
        albumentations.HorizontalFlip(p=0.5),
        albumentations.VerticalFlip(p=0.5),
        albumentations.OneOf([
            albumentations.MotionBlur(p=0.2),
            albumentations.MedianBlur(blur_limit=3, p=0.1),
            albumentations.Blur(blur_limit=3, p=0.1),
        ], p=0.2),
    ]
)

# %%
train_x_aug = []
train_y_aug = []
for i in range(len(train_x)):
    t = transform(image=train_x[i], mask=train_y[i])
    train_x_aug.append(t['image'])
    train_y_aug.append(t['mask'])

train_x_aug = np.array(train_x_aug)
train_y_aug = np.array(train_y_aug)

# %%
train_x_final = np.concatenate((train_x, train_x_aug))
train_y_final = np.concatenate((train_y, train_y_aug))

# %%
train_x_final.shape
# Out:
# (910, 512, 512, 9)

# %% [markdown]
# # Loss function

# %%
# https://gist.github.com/wassname/7793e2058c5c9dacb5212c0ac0b18a8a
def DiceLoss_square(y_true, y_pred, smooth=1):
  #create the missing data mask
    mask = tf.math.not_equal(y_true, 255)
  #apply the mask
    y_true = tf.boolean_mask(y_true, mask)
    y_pred = tf.boolean_mask(y_pred, mask)

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(K.abs(y_true_f * y_pred_f))
    return 1-((2. * intersection + smooth) / (K.sum(K.square(y_true_f),-1) + K.sum(K.square(y_pred_f),-1) + smooth))

def DiceLoss(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    return 1-((2. * intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) + smooth))

# %%
def IOU_coef(y_true, y_pred):
  #create the missing data mask
    mask = tf.math.not_equal(y_true, 255)
    #apply the mask
    y_true = tf.boolean_mask(y_true, mask)
    y_pred = tf.boolean_mask(y_pred, mask)

    #make all values > 0.5 a 1 and all others a 0
    y_pred = tf.cast((y_pred > 0.5), dtype=tf.float32)

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def tversky(y_true, y_pred, alpha = 0.75):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true, y_pred, gamma = 0.75):
    pt_1 = tversky(y_true, y_pred)
    return K.pow((1-pt_1), gamma)

# %% [markdown]
# ## Attention Layer

# %% [markdown]
# 2D Layers

# %%
def expend_as(tensor, rep,name):
    '''
    Anonymous lambda function to expand the specified axis by a factor of argument, rep.
    If tensor has shape (512,512,N), lambda will return a tensor of shape (512,512,N*rep), if specified axis=2
    '''
    my_repeat = Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': rep},  name='psi_up'+name)(tensor)
    return my_repeat


def AttnGatingBlock(x, g, inter_shape, name):
    ''' take g which is the spatially smaller signal, do a conv to get the same
    number of feature channels as x (bigger spatially)
    do a conv on x to also get same geature channels (theta_x)
    then, upsample g to be same size as x 
    add x and g (concat_xg)
    relu, 1x1 conv, then sigmoid then upsample the final - this gives us attn coefficients'''
    
    shape_x = K.int_shape(x)  # 32
    shape_g = K.int_shape(g)  # 16

    theta_x = Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same', name='xl'+name)(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

    phi_g = Conv2D(inter_shape, (1, 1), padding='same')(g)
    upsample_g = Conv2DTranspose(inter_shape, (3, 3),strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),padding='same', name='g_up'+name)(phi_g)  # 16

    concat_xg = add([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)
    psi = Conv2D(1, (1, 1), padding='same', name='psi'+name)(act_xg)
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = expend_as(upsample_psi, shape_x[3],  name)
    y = multiply([upsample_psi, x], name='q_attn'+name)

    result = Conv2D(shape_x[3], (1, 1), padding='same',name='q_attn_conv'+name)(y)
    result_bn = BatchNormalization(name='q_attn_bn'+name)(result)
    return result_bn


def UnetConv2D(input, outdim, is_batchnorm, name):
    x = Conv2D(outdim, (3, 3), strides=(1, 1), kernel_initializer=kinit, padding="same", name=name+'_1')(input)
    if is_batchnorm:
        x =BatchNormalization(name=name + '_1_bn')(x)
    x = Activation('relu', name=name + '_1_act')(x)

    x = Conv2D(outdim, (3, 3), strides=(1, 1), kernel_initializer=kinit, padding="same", name=name+'_2')(x)
    if is_batchnorm:
        x = BatchNormalization(name=name + '_2_bn')(x)
    x = Activation('relu', name=name + '_2_act')(x)
    return x


def UnetGatingSignal(input, is_batchnorm, name):
    ''' this is simply 1x1 convolution, bn, activation '''
    shape = K.int_shape(input)
    x = Conv2D(shape[3] * 1, (1, 1), strides=(1, 1), padding="same",  kernel_initializer=kinit, name=name + '_conv')(input)
    if is_batchnorm:
        x = BatchNormalization(name=name + '_bn')(x)
    x = Activation('relu', name = name + '_act')(x)
    return x

# %%
# attention gates un-net
def attn_unet(opt,input_size, lossfxn):   
    inputs = Input(shape=(input_size, input_size, 9))
    conv1 = UnetConv2D(inputs, 32, is_batchnorm=True, name='conv1')
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = UnetConv2D(pool1, 32, is_batchnorm=True, name='conv2')
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = UnetConv2D(pool2, 64, is_batchnorm=True, name='conv3')
    #conv3 = Dropout(0.2,name='drop_conv3')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = UnetConv2D(pool3, 64, is_batchnorm=True, name='conv4')
    #conv4 = Dropout(0.2, name='drop_conv4')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    center = UnetConv2D(pool4, 128, is_batchnorm=True, name='center')
    
    g1 = UnetGatingSignal(center, is_batchnorm=True, name='g1')
    attn1 = AttnGatingBlock(conv4, g1, 128, '_1')
    up1 = concatenate([Conv2DTranspose(32, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(center), attn1], name='up1')
    
    g2 = UnetGatingSignal(up1, is_batchnorm=True, name='g2')
    attn2 = AttnGatingBlock(conv3, g2, 64, '_2')
    up2 = concatenate([Conv2DTranspose(64, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up1), attn2], name='up2')

    g3 = UnetGatingSignal(up1, is_batchnorm=True, name='g3')
    attn3 = AttnGatingBlock(conv2, g3, 32, '_3')
    up3 = concatenate([Conv2DTranspose(32, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up2), attn3], name='up3')

    up4 = concatenate([Conv2DTranspose(32, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer=kinit)(up3), conv1], name='up4')
    out = Conv2D(1, (1, 1), activation='sigmoid',  kernel_initializer=kinit, name='final')(up4)
    
    model = Model(inputs=[inputs], outputs=[out])
    model.compile(optimizer=opt, loss=lossfxn, metrics=[IOU_coef])
    return model

# %%
sgd = SGD(learning_rate=0.01, momentum=0.90, decay=1e-6)
adam = Adam(learning_rate=1e-4)

# %%
input_img = Input((img_size, img_size, 9), name='img')
model = attn_unet(adam, img_size, DiceLoss_square)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 9  0           []
#                                 )]
#
#  conv1_1 (Conv2D)               (None, 512, 512, 32  2624        ['input_2[0][0]']
#                                 )
#
#  conv1_1_bn (BatchNormalization  (None, 512, 512, 32  128        ['conv1_1[0][0]']
#  )                              )
#
#  conv1_1_act (Activation)       (None, 512, 512, 32  0           ['conv1_1_bn[0][0]']
#                                 )
#
#  conv1_2 (Conv2D)               (None, 512, 512, 32  9248        ['conv1_1_act[0][0]']
#                                 )
#
#  conv1_2_bn (BatchNormalization  (None, 512, 512, 32  128        ['conv1_2[0][0]']
#  )                              )
#
#  conv1_2_act (Activation)       (None, 512, 512, 32  0           ['conv1_2_bn[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['conv1_2_act[0][0]']
#                                 )
#
#  conv2_1 (Conv2D)               (None, 256, 256, 32  9248        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2_1_bn (BatchNormalization  (None, 256, 256, 32  128        ['conv2_1[0][0]']
#  )                              )
#
#  conv2_1_act (Activation)       (None, 256, 256, 32  0           ['conv2_1_bn[0][0]']
#                                 )
#
#  conv2_2 (Conv2D)               (None, 256, 256, 32  9248        ['conv2_1_act[0][0]']
#                                 )
#
#  conv2_2_bn (BatchNormalization  (None, 256, 256, 32  128        ['conv2_2[0][0]']
#  )                              )
#
#  conv2_2_act (Activation)       (None, 256, 256, 32  0           ['conv2_2_bn[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32  0          ['conv2_2_act[0][0]']
#                                 )
#
#  conv3_1 (Conv2D)               (None, 128, 128, 64  18496       ['max_pooling2d_1[0][0]']
#                                 )
#
#  conv3_1_bn (BatchNormalization  (None, 128, 128, 64  256        ['conv3_1[0][0]']
#  )                              )
#
#  conv3_1_act (Activation)       (None, 128, 128, 64  0           ['conv3_1_bn[0][0]']
#                                 )
#
#  conv3_2 (Conv2D)               (None, 128, 128, 64  36928       ['conv3_1_act[0][0]']
#                                 )
#
#  conv3_2_bn (BatchNormalization  (None, 128, 128, 64  256        ['conv3_2[0][0]']
#  )                              )
#
#  conv3_2_act (Activation)       (None, 128, 128, 64  0           ['conv3_2_bn[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv3_2_act[0][0]']
#
#  conv4_1 (Conv2D)               (None, 64, 64, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  conv4_1_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv4_1[0][0]']
#  )
#
#  conv4_1_act (Activation)       (None, 64, 64, 64)   0           ['conv4_1_bn[0][0]']
#
#  conv4_2 (Conv2D)               (None, 64, 64, 64)   36928       ['conv4_1_act[0][0]']
#
#  conv4_2_bn (BatchNormalization  (None, 64, 64, 64)  256         ['conv4_2[0][0]']
#  )
#
#  conv4_2_act (Activation)       (None, 64, 64, 64)   0           ['conv4_2_bn[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv4_2_act[0][0]']
#
#  center_1 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  center_1_bn (BatchNormalizatio  (None, 32, 32, 128)  512        ['center_1[0][0]']
#  n)
#
#  center_1_act (Activation)      (None, 32, 32, 128)  0           ['center_1_bn[0][0]']
#
#  center_2 (Conv2D)              (None, 32, 32, 128)  147584      ['center_1_act[0][0]']
#
#  center_2_bn (BatchNormalizatio  (None, 32, 32, 128)  512        ['center_2[0][0]']
#  n)
#
#  center_2_act (Activation)      (None, 32, 32, 128)  0           ['center_2_bn[0][0]']
#
#  g1_conv (Conv2D)               (None, 32, 32, 128)  16512       ['center_2_act[0][0]']
#
#  g1_bn (BatchNormalization)     (None, 32, 32, 128)  512         ['g1_conv[0][0]']
#
#  g1_act (Activation)            (None, 32, 32, 128)  0           ['g1_bn[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 128)  16512       ['g1_act[0][0]']
#
#  g_up_1 (Conv2DTranspose)       (None, 32, 32, 128)  147584      ['conv2d[0][0]']
#
#  xl_1 (Conv2D)                  (None, 32, 32, 128)  32896       ['conv4_2_act[0][0]']
#
#  add (Add)                      (None, 32, 32, 128)  0           ['g_up_1[0][0]',
#                                                                   'xl_1[0][0]']
#
#  activation (Activation)        (None, 32, 32, 128)  0           ['add[0][0]']
#
#  psi_1 (Conv2D)                 (None, 32, 32, 1)    129         ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 1)    0           ['psi_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1)    0           ['activation_1[0][0]']
#
#  psi_up_1 (Lambda)              (None, 64, 64, 64)   0           ['up_sampling2d[0][0]']
#
#  q_attn_1 (Multiply)            (None, 64, 64, 64)   0           ['psi_up_1[0][0]',
#                                                                   'conv4_2_act[0][0]']
#
#  q_attn_conv_1 (Conv2D)         (None, 64, 64, 64)   4160        ['q_attn_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 32)  36896       ['center_2_act[0][0]']
#  ose)
#
#  q_attn_bn_1 (BatchNormalizatio  (None, 64, 64, 64)  256         ['q_attn_conv_1[0][0]']
#  n)
#
#  up1 (Concatenate)              (None, 64, 64, 96)   0           ['conv2d_transpose[0][0]',
#                                                                   'q_attn_bn_1[0][0]']
#
#  g2_conv (Conv2D)               (None, 64, 64, 96)   9312        ['up1[0][0]']
#
#  g2_bn (BatchNormalization)     (None, 64, 64, 96)   384         ['g2_conv[0][0]']
#
#  g2_act (Activation)            (None, 64, 64, 96)   0           ['g2_bn[0][0]']
#
#  g3_conv (Conv2D)               (None, 64, 64, 96)   9312        ['up1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   6208        ['g2_act[0][0]']
#
#  g3_bn (BatchNormalization)     (None, 64, 64, 96)   384         ['g3_conv[0][0]']
#
#  g_up_2 (Conv2DTranspose)       (None, 64, 64, 64)   36928       ['conv2d_1[0][0]']
#
#  xl_2 (Conv2D)                  (None, 64, 64, 64)   16448       ['conv3_2_act[0][0]']
#
#  g3_act (Activation)            (None, 64, 64, 96)   0           ['g3_bn[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['g_up_2[0][0]',
#                                                                   'xl_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   3104        ['g3_act[0][0]']
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['add_1[0][0]']
#
#  g_up_3 (Conv2DTranspose)       (None, 128, 128, 32  9248        ['conv2d_2[0][0]']
#                                 )
#
#  xl_3 (Conv2D)                  (None, 128, 128, 32  4128        ['conv2_2_act[0][0]']
#                                 )
#
#  psi_2 (Conv2D)                 (None, 64, 64, 1)    65          ['activation_2[0][0]']
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['g_up_3[0][0]',
#                                 )                                 'xl_3[0][0]']
#
#  activation_3 (Activation)      (None, 64, 64, 1)    0           ['psi_2[0][0]']
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['add_2[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_3[0][0]']
#
#  psi_3 (Conv2D)                 (None, 128, 128, 1)  33          ['activation_4[0][0]']
#
#  psi_up_2 (Lambda)              (None, 128, 128, 64  0           ['up_sampling2d_1[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 128, 128, 1)  0           ['psi_3[0][0]']
#
#  q_attn_2 (Multiply)            (None, 128, 128, 64  0           ['psi_up_2[0][0]',
#                                 )                                 'conv3_2_act[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_5[0][0]']
#
#  q_attn_conv_2 (Conv2D)         (None, 128, 128, 64  4160        ['q_attn_2[0][0]']
#                                 )
#
#  psi_up_3 (Lambda)              (None, 256, 256, 32  0           ['up_sampling2d_2[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 64  55360      ['up1[0][0]']
#  spose)                         )
#
#  q_attn_bn_2 (BatchNormalizatio  (None, 128, 128, 64  256        ['q_attn_conv_2[0][0]']
#  n)                             )
#
#  q_attn_3 (Multiply)            (None, 256, 256, 32  0           ['psi_up_3[0][0]',
#                                 )                                 'conv2_2_act[0][0]']
#
#  up2 (Concatenate)              (None, 128, 128, 12  0           ['conv2d_transpose_1[0][0]',
#                                 8)                                'q_attn_bn_2[0][0]']
#
#  q_attn_conv_3 (Conv2D)         (None, 256, 256, 32  1056        ['q_attn_3[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 32  36896      ['up2[0][0]']
#  spose)                         )
#
#  q_attn_bn_3 (BatchNormalizatio  (None, 256, 256, 32  128        ['q_attn_conv_3[0][0]']
#  n)                             )
#
#  up3 (Concatenate)              (None, 256, 256, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'q_attn_bn_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 32  18464      ['up3[0][0]']
#  spose)                         )
#
#  up4 (Concatenate)              (None, 512, 512, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv1_2_act[0][0]']
#
#  final (Conv2D)                 (None, 512, 512, 1)  65          ['up4[0][0]']
#
# ==================================================================================================
# Total params: 851,044
# Trainable params: 848,804
# Non-trainable params: 2,240
# __________________________________________________________________________________________________

# %%
MODEL_NAME = "test_tensorflow_attn_unet.h5"

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1)
    # ModelCheckpoint('/models/' + MODEL_NAME, verbose=1, save_best_only=True, save_weights_only=False)
]

# %%
print(type(train_x_final[0,0,0,8]), type(train_y[0,0,0]))
print(type(test_x[0,0,0,0]), type(test_y[0,0,0]))
# Out:
# <class 'numpy.uint8'> <class 'numpy.float32'>
# <class 'numpy.uint8'> <class 'numpy.float32'>

# %%
print("max train_x:", np.amax(train_x), "min train_x:", np.amin(train_x))
print("max train_x_aug:", np.amax(train_x_aug), "min train_x_aug:", np.amin(train_x_aug))
print("max test_x:", np.amax(test_x), "min test_x:", np.amin(test_x))
print("max train_y:", np.amax(train_y), "min train_y:", np.amin(train_y))
print("max test_y:", np.amax(test_y), "min test_y:", np.amin(test_y))
# Out:
# max train_x: 255 min train_x: 0
# max train_x_aug: 255 min train_x_aug: 0
# max test_x: 255 min test_x: 0
# max train_y: 255.0 min train_y: 0.0
# max test_y: 255.0 min test_y: 0.0

# %%
results = model.fit(train_x_final, train_y_final, batch_size=8, epochs=100, callbacks=callbacks,
                    validation_data=(test_x, test_y))
# Out:
# Epoch 1/100
# 111/111 [==============================] - 34s 284ms/step - loss: 0.3880 - IOU_coef: 0.4585 - val_loss: 0.7548 - val_IOU_coef: 0.0996 - lr: 1.0000e-04
# Epoch 2/100
# 111/111 [==============================] - 31s 284ms/step - loss: 0.2423 - IOU_coef: 0.5964 - val_loss: 0.4876 - val_IOU_coef: 0.3924 - lr: 1.0000e-04
# Epoch 3/100
# 111/111 [==============================] - 32s 287ms/step - loss: 0.2294 - IOU_coef: 0.6037 - val_loss: 0.3694 - val_IOU_coef: 0.4732 - lr: 1.0000e-04
# Epoch 4/100
# 111/111 [==============================] - 32s 289ms/step - loss: 0.2200 - IOU_coef: 0.6190 - val_loss: 0.3342 - val_IOU_coef: 0.5402 - lr: 1.0000e-04
# Epoch 5/100
# 111/111 [==============================] - 32s 290ms/step - loss: 0.2080 - IOU_coef: 0.6350 - val_loss: 0.3888 - val_IOU_coef: 0.4246 - lr: 1.0000e-04
# Epoch 6/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.2124 - IOU_coef: 0.6226 - val_loss: 0.3927 - val_IOU_coef: 0.4569 - lr: 1.0000e-04
# Epoch 7/100
# 111/111 [==============================] - 32s 290ms/step - loss: 0.1786 - IOU_coef: 0.6661 - val_loss: 0.3322 - val_IOU_coef: 0.5129 - lr: 1.0000e-04
# Epoch 8/100
# 111/111 [==============================] - 32s 290ms/step - loss: 0.2095 - IOU_coef: 0.6336 - val_loss: 0.3615 - val_IOU_coef: 0.5108 - lr: 1.0000e-04
# Epoch 9/100
# 111/111 [==============================] - 32s 290ms/step - loss: 0.2000 - IOU_coef: 0.6475 - val_loss: 0.3263 - val_IOU_coef: 0.4995 - lr: 1.0000e-04
# Epoch 10/100
# 111/111 [==============================] - 32s 290ms/step - loss: 0.1633 - IOU_coef: 0.6937 - val_loss: 0.3239 - val_IOU_coef: 0.5420 - lr: 1.0000e-04
# Epoch 11/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1909 - IOU_coef: 0.6564 - val_loss: 0.3304 - val_IOU_coef: 0.4982 - lr: 1.0000e-04
# Epoch 12/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1872 - IOU_coef: 0.6644 - val_loss: 0.3204 - val_IOU_coef: 0.5488 - lr: 1.0000e-04
# Epoch 13/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1899 - IOU_coef: 0.6563 - val_loss: 0.3445 - val_IOU_coef: 0.5226 - lr: 1.0000e-04
# Epoch 14/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1762 - IOU_coef: 0.6762 - val_loss: 0.3566 - val_IOU_coef: 0.5176 - lr: 1.0000e-04
# Epoch 15/100
# 111/111 [==============================] - ETA: 0s - loss: 0.1748 - IOU_coef: 0.6755
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-05.
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1748 - IOU_coef: 0.6755 - val_loss: 0.3459 - val_IOU_coef: 0.5244 - lr: 1.0000e-04
# Epoch 16/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1704 - IOU_coef: 0.6867 - val_loss: 0.3271 - val_IOU_coef: 0.4905 - lr: 1.0000e-05
# Epoch 17/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1778 - IOU_coef: 0.6741 - val_loss: 0.3180 - val_IOU_coef: 0.5005 - lr: 1.0000e-05
# Epoch 18/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1584 - IOU_coef: 0.6985 - val_loss: 0.3177 - val_IOU_coef: 0.5387 - lr: 1.0000e-05
# Epoch 19/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1627 - IOU_coef: 0.6945 - val_loss: 0.3123 - val_IOU_coef: 0.5466 - lr: 1.0000e-05
# Epoch 20/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1661 - IOU_coef: 0.6898 - val_loss: 0.3206 - val_IOU_coef: 0.5350 - lr: 1.0000e-05
# Epoch 21/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1751 - IOU_coef: 0.6817 - val_loss: 0.3159 - val_IOU_coef: 0.5390 - lr: 1.0000e-05
# Epoch 22/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1632 - IOU_coef: 0.6964 - val_loss: 0.3171 - val_IOU_coef: 0.5372 - lr: 1.0000e-05
# Epoch 23/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1628 - IOU_coef: 0.6951 - val_loss: 0.3130 - val_IOU_coef: 0.5436 - lr: 1.0000e-05
# Epoch 24/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1629 - IOU_coef: 0.6933 - val_loss: 0.3171 - val_IOU_coef: 0.5423 - lr: 1.0000e-05
# Epoch 25/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1589 - IOU_coef: 0.7018 - val_loss: 0.3136 - val_IOU_coef: 0.5426 - lr: 1.0000e-05
# Epoch 26/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1626 - IOU_coef: 0.6963 - val_loss: 0.3112 - val_IOU_coef: 0.5459 - lr: 1.0000e-05
# Epoch 27/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1605 - IOU_coef: 0.6980 - val_loss: 0.3097 - val_IOU_coef: 0.5491 - lr: 1.0000e-05
# Epoch 28/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1624 - IOU_coef: 0.6952 - val_loss: 0.3117 - val_IOU_coef: 0.5448 - lr: 1.0000e-05
# Epoch 29/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1625 - IOU_coef: 0.6948 - val_loss: 0.3085 - val_IOU_coef: 0.5512 - lr: 1.0000e-05
# Epoch 30/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1646 - IOU_coef: 0.6949 - val_loss: 0.3090 - val_IOU_coef: 0.5563 - lr: 1.0000e-05
# Epoch 31/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1553 - IOU_coef: 0.7057 - val_loss: 0.3182 - val_IOU_coef: 0.5399 - lr: 1.0000e-05
# Epoch 32/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1545 - IOU_coef: 0.7056 - val_loss: 0.3092 - val_IOU_coef: 0.5506 - lr: 1.0000e-05
# Epoch 33/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1417 - IOU_coef: 0.7231 - val_loss: 0.3079 - val_IOU_coef: 0.5525 - lr: 1.0000e-05
# Epoch 34/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1575 - IOU_coef: 0.6998 - val_loss: 0.3075 - val_IOU_coef: 0.5514 - lr: 1.0000e-05
# Epoch 35/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1524 - IOU_coef: 0.7096 - val_loss: 0.3066 - val_IOU_coef: 0.5548 - lr: 1.0000e-05
# Epoch 36/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1574 - IOU_coef: 0.7030 - val_loss: 0.3064 - val_IOU_coef: 0.5190 - lr: 1.0000e-05
# Epoch 37/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1516 - IOU_coef: 0.7128 - val_loss: 0.3110 - val_IOU_coef: 0.5492 - lr: 1.0000e-05
# Epoch 38/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1465 - IOU_coef: 0.7186 - val_loss: 0.3184 - val_IOU_coef: 0.5394 - lr: 1.0000e-05
# Epoch 39/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1483 - IOU_coef: 0.7153 - val_loss: 0.3096 - val_IOU_coef: 0.5228 - lr: 1.0000e-05
# Epoch 40/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1553 - IOU_coef: 0.7050 - val_loss: 0.3088 - val_IOU_coef: 0.5542 - lr: 1.0000e-05
# Epoch 41/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1531 - IOU_coef: 0.7108 - val_loss: 0.3057 - val_IOU_coef: 0.5551 - lr: 1.0000e-05
# Epoch 42/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1551 - IOU_coef: 0.7045 - val_loss: 0.3068 - val_IOU_coef: 0.5599 - lr: 1.0000e-05
# Epoch 43/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1553 - IOU_coef: 0.7067 - val_loss: 0.3135 - val_IOU_coef: 0.5456 - lr: 1.0000e-05
# Epoch 44/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1651 - IOU_coef: 0.6934 - val_loss: 0.3106 - val_IOU_coef: 0.5485 - lr: 1.0000e-05
# Epoch 45/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1495 - IOU_coef: 0.7132 - val_loss: 0.3072 - val_IOU_coef: 0.5538 - lr: 1.0000e-05
# Epoch 46/100
# 111/111 [==============================] - 32s 291ms/step - loss: 0.1271 - IOU_coef: 0.7462 - val_loss: 0.3139 - val_IOU_coef: 0.5453 - lr: 1.0000e-05
# Epoch 47/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1502 - IOU_coef: 0.7124 - val_loss: 0.3189 - val_IOU_coef: 0.5411 - lr: 1.0000e-05
# Epoch 48/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1518 - IOU_coef: 0.7120 - val_loss: 0.3170 - val_IOU_coef: 0.5483 - lr: 1.0000e-05
# Epoch 49/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1519 - IOU_coef: 0.7130 - val_loss: 0.3100 - val_IOU_coef: 0.5528 - lr: 1.0000e-05
# Epoch 50/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1539 - IOU_coef: 0.7081 - val_loss: 0.3044 - val_IOU_coef: 0.5570 - lr: 1.0000e-05
# Epoch 51/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1374 - IOU_coef: 0.7291 - val_loss: 0.3020 - val_IOU_coef: 0.5611 - lr: 1.0000e-05
# Epoch 52/100
# 111/111 [==============================] - 32s 293ms/step - loss: 0.1522 - IOU_coef: 0.7136 - val_loss: 0.3115 - val_IOU_coef: 0.5529 - lr: 1.0000e-05
# Epoch 53/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1473 - IOU_coef: 0.7156 - val_loss: 0.3127 - val_IOU_coef: 0.5537 - lr: 1.0000e-05
# Epoch 54/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1472 - IOU_coef: 0.7145 - val_loss: 0.3060 - val_IOU_coef: 0.5618 - lr: 1.0000e-05
# Epoch 55/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1529 - IOU_coef: 0.7058 - val_loss: 0.3187 - val_IOU_coef: 0.5479 - lr: 1.0000e-05
# Epoch 56/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1704 - IOU_coef: 0.6896 - val_loss: 0.3200 - val_IOU_coef: 0.5461 - lr: 1.0000e-05
# Epoch 57/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1437 - IOU_coef: 0.7254 - val_loss: 0.3123 - val_IOU_coef: 0.5465 - lr: 1.0000e-05
# Epoch 58/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1503 - IOU_coef: 0.7129 - val_loss: 0.3109 - val_IOU_coef: 0.5536 - lr: 1.0000e-05
# Epoch 59/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1462 - IOU_coef: 0.7183 - val_loss: 0.3198 - val_IOU_coef: 0.5401 - lr: 1.0000e-05
# Epoch 60/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1515 - IOU_coef: 0.7137 - val_loss: 0.3133 - val_IOU_coef: 0.5504 - lr: 1.0000e-05
# Epoch 61/100
# 111/111 [==============================] - 32s 292ms/step - loss: 0.1521 - IOU_coef: 0.7132 - val_loss: 0.3113 - val_IOU_coef: 0.5515 - lr: 1.0000e-05
# Epoch 61: early stopping

# %% [markdown]
# With difficult id in train (train IoU):
# - IOU = 0.6394 Unet with attention + tversky loss + adam learning_rate=1e-3 + alpha = 0.75
# - IOU = 0.661 Unet with attention + tversky loss + adam learning_rate=1e-4 + alpha = 0.75
# - IOU = 0.6209 Unet with attention +  tversky loss + adam learning_rate=1e-4 + alpha = 0.8
# - IOU = 0.5939 Unet with attention + tversky loss + adam learning_rate=1e-4 + alpha = 0.5
# - IOU = 0.6115 Unet with attention + DICE loss + adam
# - IOU = 0.5788 Unet with attention + DICE loss + sgd
#
# Without difficult id in train (train IoU): (still have to automate it though) (old)
# - IOU = 0.6555 Unet with attention + tversky loss + adam + learning_rate=1e-4 + alpha = 0.75
# - IOU = 0.6554 Unet with attention + tversky loss + learning_rate=5e-4 + alpha 0.75
# - IOU = 0.6058 Unet with attention + tversky loss + learning_rate=1e-3 + alpha 0.75
# - IOU = 0.7462 Unet with attention + learning_rate=1e-4 + alpha 0.75 + dice_square

# %% [markdown]
# Difficult chips: https://github.com/drivendataorg/stac-overflow/blob/main/3rd_Place/01-ewl-stac.ipynb
# hxu, jja, pxs --> keep in training

# %%
plt.figure(figsize=(8, 8))
plt.title(f"Learning curve - IoU: {round(max(results.history['IOU_coef']), 4)}")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()
